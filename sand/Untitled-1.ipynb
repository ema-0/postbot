# %%
import asyncio

# %%
async def main():
    print('hello')
    await asyncio.sleep(1)
    print('world')

await main()
# Out:
# hello
# world

# %%
type(main())
# Out:
# /var/folders/7b/lw66jxrn6h52gl2t79q4fzvr0000gp/T/ipykernel_37055/449241671.py:1: RuntimeWarning: coroutine 'main' was never awaited
#   type(main())
# ...
# coroutine
